# %% [markdown]
# # Dimensionality Reduction and 3D Visualization of MNIST Dataset
#
# ## Introduction
# This project aims to reduce the dimensionality of the MNIST dataset using PCA and t-SNE, and visually explore the clustering of digits in a 3D space. This can provide insights into the inherent structures of the dataset and the effectiveness of these reduction techniques.

# %% [markdown]
# ## 1. Data Loading
# Load the MNIST dataset which consists of 70,000 images of handwritten digits.

# %%
from tensorflow.keras.datasets import mnist
import numpy as np

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
X = np.concatenate([train_images, test_images]).reshape(-1, 28*28)
y = np.concatenate([train_labels, test_labels])
# Normalize the data
X = X.astype('float32') / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## 2. Data Preprocessing
# Flatten the images and scale the pixel values to [0, 1].

# %%
# This step has already been completed in the data loading cell.

# %% [markdown]
# ## 3. Applying PCA and t-SNE for Dimensionality Reduction
# Reduce the dimensions of the data to three dimensions using PCA and t-SNE.

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# PCA Reduction
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# t-SNE Reduction
tsne = TSNE(n_components=3, verbose=0, perplexity=40, n_iter=300)
X_tsne = tsne.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 70000 samples in 0.043s...
# [t-SNE] Computed neighbors for 70000 samples in 344.439s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 70000
# [t-SNE] Computed conditional probabilities for sample 2000 / 70000
# [t-SNE] Computed conditional probabilities for sample 3000 / 70000
# [t-SNE] Computed conditional probabilities for sample 4000 / 70000
# [t-SNE] Computed conditional probabilities for sample 5000 / 70000
# [t-SNE] Computed conditional probabilities for sample 6000 / 70000
# [t-SNE] Computed conditional probabilities for sample 7000 / 70000
# [t-SNE] Computed conditional probabilities for sample 8000 / 70000
# [t-SNE] Computed conditional probabilities for sample 9000 / 70000
# ...

# %% [markdown]
# ## 4. 3D Visualization of the Reduced Data
# Visualize the reduced data using 3D plots to observe the clustering of different digits.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# PCA Visualization
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(121, projection='3d')
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=y, cmap='tab10')
plt.colorbar(scatter, ax=ax)
ax.set_title('PCA Reduction')

# t-SNE Visualization
ax = fig.add_subplot(122, projection='3d')
scatter = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], c=y, cmap='tab10')
plt.colorbar(scatter, ax=ax)
ax.set_title('t-SNE Reduction')
plt.show()

# %% [markdown]
# ## 5. Conclusion
# Discuss the effectiveness of PCA and t-SNE in revealing the underlying structure of the MNIST dataset and explore potential use cases for these dimensionality reduction techniques in other domains.
